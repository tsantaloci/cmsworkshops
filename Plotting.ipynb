# %% [markdown]
# ##Plotting Lesson

# %%
import numpy
import os

# %%
distance_file = os.path.join('data','distance_data_headers.csv')
distances = numpy.genfromtxt(fname=distance_file, delimiter=',',dtype='unicode')
print(distances)
# Out:
# [['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']
#  ['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %%
headers = distances[0] ##slicing
print(headers)
# Out:
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']

# %%
data= distances[1:]
print(data)
data=data.astype(numpy.float)
# Out:
# [['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ['3' '9.0066' '6.0637' '13.0924' '11.3043']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %%
import matplotlib.pyplot as plt ##library name as nickname for library

# %%
plt.figure()
plt.plot(data[:,0],data[:,1]) # plotting every row and index 1 column

# %%
sample = headers[1]

plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstroms)')
fig_1 = plt.plot(data[:,0], data[:,1], label=sample)
plt.legend()

plt.savefig(F'{sample}.png')

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstroms)')
plt.plot(data[:,0],data[:,1], label=headers[1])
plt.plot(data[:,0],data[:,2], label=headers[2])
plt.legend()

# %%
plt.figure()
for col in range(1,len(headers)):
    fig = plt.plot(data[:,0],data[:,col], label=headers[col])
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstroms)')
plt.legend()

# %%
plt.figure()
for col in range(1,len(headers)):
    fig_1 = plt.plot(data[:,0], data[:,1], label=sample)
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstroms)')
plt.legend()

# %%
 plt.figure()
for col in range(1,len(headers)):
    fig_1 = plt.plot(data[:,0], data[:,2], label=sample)
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstroms)')
plt.legend()

# %%
plt.figure()
for col in range(1,len(headers)):
    fig_1 = plt.plot(data[:,0], data[:,1], label=sample)
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstroms)')
plt.legend()

# %%
plt.figure()
for col in range(1,len(headers)):
    figure=plt.figure()
    fig = plt.plot(data[:,0],data[:,col], label=headers[col])
    plt.xlabel('Simulation Frame')
    plt.ylabel('Distance (angstroms)')
    plt.legend()
    plt.savefig(F'{headers[col]}.png', dpi=300)
